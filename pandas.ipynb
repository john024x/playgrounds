# %%
import pandas as pd
import numpy as np

# %%
psg_players = pd.Series(['Navas','Mbappe','Neymar','Messi'], #especifica los valores
          index = [1,7,10,30] #especifica el indice, si no se pone, se hace una lista ordenada
          )
psg_players
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
dict = {1:'Navas', 7:'Mbappe',10:'Neymar',30:'Messi'}
pd.Series(dict) #Otra manera de crear una serie
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players[7]
# Out:
# 'Mbappe'

# %%
dict = {'Jugador': ['Navas','Mbappe','Neymar','Messi'],
        'Altura': [183,176,177,176],
        'Goles': [2,200,200,200]
        }

# %%
df_dataplayers = pd.DataFrame(dict,index=[1,7,10,30])
df_dataplayers
# Out:
#    Jugador  Altura  Goles
# 1    Navas     183      2
# 7   Mbappe     176    200
# 10  Neymar     177    200
# 30   Messi     176    200

# %%
df_dataplayers.columns
# Out:
# Index(['Jugador', 'Altura', 'Goles'], dtype='object')

# %%
#leer archivos

# %%
df_books = pd.read_csv('/content/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv',sep=',',header=0)
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
#----

# %%
#iloc y loc

# %%
df_books[0:4]
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
# 3                   1984 (Signet Classics)       George Orwell          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction
# 3    21424      6  2017      Fiction

# %%
df_books[['Name','Author']]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# ..                        ...
# 545               Jeff Kinney
# 546               Jen Sincero
# ...

# %%
df_books.loc[0:4,['Name','Author']] #Busqueda por labels
# Out:
#                                                 Name                    Author
# 0                      10-Day Green Smoothie Cleanse                  JJ Smith
# 1                                  11/22/63: A Novel              Stephen King
# 2            12 Rules for Life: An Antidote to Chaos        Jordan B. Peterson
# 3                             1984 (Signet Classics)             George Orwell
# 4  5,000 Awesome Facts (About Everything!) (Natio...  National Geographic Kids

# %%
df_books.loc[:,['Price']] *2 #Se pueden operar con los valores del dataframe
# Out:
#      Price
# 0       16
# 1       44
# 2       30
# 3       12
# 4       24
# ..     ...
# 545     16
# 546     16
# 547     16
# 548     16
# 549     16
#
# [550 rows x 1 columns]

# %%
df_books.iloc[:,0:3] #Esta busqueda es por el indice, en lugar de por el label
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating
# 0                    JJ Smith          4.7
# 1                Stephen King          4.6
# 2          Jordan B. Peterson          4.7
# 3               George Orwell          4.7
# 4    National Geographic Kids          4.8
# ...

# %%
#eliminar datos en pandas

# %%
df_books.drop('Genre',axis=1).head(2) #Con el drop se borra de la sentencia, mas no del dataframe original
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %%
#df_books.drop('Genre',axis=1,inplace=True) #Poniendo el inplace, se borra del dataframe original

# %%
del df_books['Price'] #funcion propia de python, sirve para borrar tambien del dataframe

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Year
# 0                    JJ Smith          4.7    17350  2016
# 1                Stephen King          4.6     2052  2011
# 2          Jordan B. Peterson          4.7    18979  2018
# 3               George Orwell          4.7    21424  2017
# ...

# %%
df_books.drop(0,axis=0).head(2) #borrado de filas
# Out:
#                                       Name              Author  User Rating  \
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Year
# 1     2052  2011
# 2    18979  2018

# %%
df_books.drop(range(0,10),axis=0).head(2) #borrado de filas
# Out:
#                                                  Name            Author  \
# 10                          A Man Called Ove: A Novel   Fredrik Backman
# 11  A Patriot's History of the United States: From...  Larry Schweikart
#
#     User Rating  Reviews  Year
# 10          4.6    23848  2017
# 11          4.6      460  2010

# %%
#add columns

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Year
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350  2016
# 1              11/22/63: A Novel  Stephen King          4.6     2052  2011

# %%
df_books['New column'] = np.nan #Creacion de nuevas columnas

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Year  New column
# 0                    JJ Smith          4.7    17350  2016         NaN
# 1                Stephen King          4.6     2052  2011         NaN
# 2          Jordan B. Peterson          4.7    18979  2018         NaN
# ...

# %%
data = np.arange(0,df_books.shape[0])

# %%
df_books['Range'] = data

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Year  New column  Range
# 0                    JJ Smith          4.7    17350  2016         NaN      0
# 1                Stephen King          4.6     2052  2011         NaN      1
# ...

# %%
#add rows

# %%
df_books.append(df_books)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Year  New column  Range
# 0                    JJ Smith          4.7    17350  2016         NaN      0
# 1                Stephen King          4.6     2052  2011         NaN      1
# ...

# %%
#manejo de valores nulos

# %%
dictio = {'Col1':[1,2,3,np.nan],
 'Col2':[4,5,np.nan,6],
 'Col3':['a','b',7,None],
 }

# %%
df = pd.DataFrame(dictio)
df
# Out:
#    Col1  Col2  Col3
# 0   1.0   4.0     a
# 1   2.0   5.0     b
# 2   3.0   NaN     7
# 3   NaN   6.0  None

# %%
df.isnull() #Verificar si son nulos
# Out:
#     Col1   Col2   Col3
# 0  False  False  False
# 1  False  False  False
# 2  False   True  False
# 3   True  False   True

# %%
df.isnull()*1
# Out:
#    Col1  Col2  Col3
# 0     0     0     0
# 1     0     0     0
# 2     0     1     0
# 3     1     0     1

# %%
df.fillna('Missing') #rellena los espacios nulos con Missing
# Out:
#       Col1     Col2     Col3
# 0      1.0      4.0        a
# 1      2.0      5.0        b
# 2      3.0  Missing        7
# 3  Missing      6.0  Missing

# %%
df.interpolate() #Interpola una serie
# Out:
#    Col1  Col2  Col3
# 0   1.0   4.0     a
# 1   2.0   5.0     b
# 2   3.0   5.5     7
# 3   3.0   6.0  None

# %%
df.dropna() #dropea los datos que contienen sets nulos
# Out:
#    Col1  Col2 Col3
# 0   1.0   4.0    a
# 1   2.0   5.0    b

# %%
#Filtrado por condiciones

# %%
mayor_2016 = df_books['Year'] > 2016

# %%
df_books[mayor_2016]
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# ..                                                 ...
# 544                                             Wonder
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Year  New column  Range
# 2          Jordan B. Peterson          4.7    18979  2018         NaN      2
# 3               George Orwell          4.7    21424  2017         NaN      3
# ...

# %%
genre_fiction = df_books['Genre'] == 'Fiction'

# %%
df_books[genre_fiction & -mayor_2016] #el - sirve para
# Out:
#                                                   Name               Author  \
# 1                                    11/22/63: A Novel         Stephen King
# 5        A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6    A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 9                            A Man Called Ove: A Novel      Fredrik Backman
# 20                         All the Light We Cannot See        Anthony Doerr
# ..                                                 ...                  ...
# 538  Winter of the World: Book Two of the Century T...          Ken Follett
# 540                                             Wonder        R. J. Palacio
# 541                                             Wonder        R. J. Palacio
# 542                                             Wonder        R. J. Palacio
# 543                                             Wonder        R. J. Palacio
#
#      User Rating  Reviews  Price  Year    Genre
# ...

# %%
#funciones de pandas

# %%
df_books.info() #info general del dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
df_books.describe() #de las columnas numericas da datos estadisticos
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
df_books.head() #muestra solo una porcion del dataset
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df_books.memory_usage(deep=True) #cuanta memorai esta usando el dataset
# Out:
# Index            128
# Name           59737
# Author         39078
# User Rating     4400
# Reviews         4400
# Price           4400
# Year            4400
# Genre          36440
# dtype: int64

# %%
df_books.drop_duplicates(keep='last') #elimina los duplicados
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#Countby

# %%
df_books.groupby('Author').mean()
# Out:
#                             User Rating       Reviews      Price         Year
# Author
# Abraham Verghese               4.600000   4866.000000  11.000000  2010.500000
# Adam Gasiewski                 4.400000   3113.000000   6.000000  2017.000000
# Adam Mansbach                  4.800000   9568.000000   9.000000  2011.000000
# Adir Levy                      4.800000   8170.000000  13.000000  2019.000000
# Admiral William H. McRaven     4.700000  10199.000000  11.000000  2017.000000
# ...                                 ...           ...        ...          ...
# Walter Isaacson                4.566667   6222.666667  20.333333  2013.333333
# William Davis                  4.400000   7497.000000   6.000000  2012.500000
# William P. Young               4.600000  19720.000000   8.000000  2013.000000
# Wizards RPG Team               4.800000  16990.000000  27.000000  2018.000000
# Zhi Gang Sha                   4.600000    128.500000  11.500000  2011.000000
#
# [248 rows x 4 columns]

# %%
df_books.groupby('Author').mean().loc['Zhi Gang Sha']
# Out:
# User Rating       4.6
# Reviews         128.5
# Price            11.5
# Year           2011.0
# Name: Zhi Gang Sha, dtype: float64
